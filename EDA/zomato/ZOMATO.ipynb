# %% [markdown]
# # Columns description

# %% [markdown]
# 1.url contains the url of the restaurant in the zomato website
#
# 2.address contains the address of the restaurant in Bengaluru.
#
# 3.name contains the name of the restaurant.
#
# 4.online_order whether online ordering is available in the restaurant or not.
#
# 5.book_table table book option available or not.
#
# 6.ate contains the overall rating of the restaurant out of 5.
#
# 7.votes contains total number of rating for the restaurant as of the above mentioned date.
#
# 8.phone contains the phone number of the restaurant.
#
# 9.location contains the neighborhood in which the restaurant is located.
#
# 10.rest_type restaurant type.
#
# 11.dish_liked dishes people liked in the restaurant.
#
# 12.cuisines food styles, separated by comma.
#
# 13.approx_cost(for two people) contains the approximate cost for meal for two people.
#
# 14.reviews_list list of tuples containing reviews for the restaurant, each tuple.
#
# 15.menu_item contains list of menus available in the restaurant.
#
# 16.listed_in(type) type of meal.
#
# 17.listed_in(city) contains the neighborhood in which the restaurant is listed

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df=pd.read_csv('zomato1.csv')
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df.replace('NEW',0,inplace=True)

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 0, '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df.replace('-',0,inplace=True)

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 0, '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
def ratecolumn(value):
    value = str(value).split('/')
    value = value[0]
    return value

# %%
df['rate'] = df['rate'].apply(ratecolumn)
df['rate'].head()
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: object

# %%
df['rate']=df['rate'].astype(float)

# %%
df['rate'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 0. , 2.9, 3.5, nan, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4,
#        2.2, 2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
df['rate'].fillna(df['rate'].mean(),inplace=True)

# %%
df['rate'].unique()
# Out:
# array([4.1       , 3.8       , 3.7       , 3.6       , 4.6       ,
#        4.        , 4.2       , 3.9       , 3.1       , 3.        ,
#        3.2       , 3.3       , 2.8       , 4.4       , 4.3       ,
#        0.        , 2.9       , 3.5       , 3.50869783, 2.6       ,
#        3.4       , 4.5       , 2.5       , 2.7       , 4.7       ,
#        2.4       , 2.2       , 2.3       , 4.8       , 4.9       ,
#        2.1       , 2.        , 1.8       ])

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (51717, 17)

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                               0
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23222 entries, 0 to 51715
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23222 non-null  object
#  1   address                      23222 non-null  object
#  2   name                         23222 non-null  object
#  3   online_order                 23222 non-null  object
#  4   book_table                   23222 non-null  object
#  5   rate                         23222 non-null  float64
#  6   votes                        23222 non-null  int64
#  7   phone                        23222 non-null  object
#  8   location                     23222 non-null  object
#  9   rest_type                    23222 non-null  object
#  10  dish_liked                   23222 non-null  object
#  11  cuisines                     23222 non-null  object
#  12  approx_cost(for two people)  23222 non-null  object
# ...

# %%
df['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '750', '200', '850', '1,200', '150', '350', '250', '1,500',
#        '1,300', '1,000', '100', '900', '1,100', '1,600', '950', '230',
#        '1,700', '1,400', '1,350', '2,200', '2,000', '1,800', '1,900',
#        '180', '330', '2,500', '2,100', '3,000', '2,800', '3,400', '40',
#        '1,250', '3,500', '4,000', '2,400', '1,450', '3,200', '6,000',
#        '1,050', '4,100', '2,300', '120', '2,600', '5,000', '3,700',
#        '1,650', '2,700', '4,500'], dtype=object)

# %%
def handlecomma(value):
    value = str(value)
    if ',' in value:
        value = value.replace(',', '')
        return value
    else:
        return value

# %%
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].apply(handlecomma)
df['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '750', '200', '850', '1200', '150', '350', '250', '1500', '1300',
#        '1000', '100', '900', '1100', '1600', '950', '230', '1700', '1400',
#        '1350', '2200', '2000', '1800', '1900', '180', '330', '2500',
#        '2100', '3000', '2800', '3400', '40', '1250', '3500', '4000',
#        '2400', '1450', '3200', '6000', '1050', '4100', '2300', '120',
#        '2600', '5000', '3700', '1650', '2700', '4500'], dtype=object)

# %%
cuisines = df['cuisines'].value_counts()

# %%
df['cuisines'].head()
# Out:
# 0    North Indian, Mughlai, Chinese
# 1       Chinese, North Indian, Thai
# 2            Cafe, Mexican, Italian
# 3        South Indian, North Indian
# 4          North Indian, Rajasthani
# Name: cuisines, dtype: object

# %%
df['cuisines'].unique()
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ..., 'Andhra, Hyderabadi, Biryani',
#        'Andhra, North Indian, South Indian', 'Thai, Chinese, Momos'],
#       dtype=object)

# %%
df['rest_type'].unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe', 'Delivery',
#        'Dessert Parlor', 'Pub', 'Beverage Shop', 'Bar',
#        'Takeaway, Delivery', 'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Pub, Casual Dining', 'Casual Dining, Bar', 'Bakery', 'Sweet Shop',
#        'Dessert Parlor, Beverage Shop', 'Beverage Shop, Quick Bites',
#        'Microbrewery, Casual Dining', 'Sweet Shop, Quick Bites', 'Lounge',
#        'Food Court', 'Cafe, Bakery', 'Microbrewery', 'Kiosk', 'Pub, Bar',
#        'Casual Dining, Pub', 'Cafe, Quick Bites', 'Lounge, Bar',
#        'Bakery, Quick Bites', 'Dessert Parlor, Quick Bites',
#        'Bar, Casual Dining', 'Beverage Shop, Dessert Parlor',
#        'Casual Dining, Microbrewery', 'Mess', 'Lounge, Casual Dining',
#        'Cafe, Dessert Parlor', 'Dessert Parlor, Cafe',
#        'Bakery, Dessert Parlor', 'Quick Bites, Sweet Shop', 'Takeaway',
# ...

# %%
df['location'].value_counts(ascending=False)
# Out:
# Koramangala 5th Block    1784
# BTM                      1460
# Indiranagar              1350
# HSR                      1162
# Jayanagar                1047
#                          ...
# Yelahanka                   2
# Kanakapura Road             2
# West Bangalore              2
# Rajarajeshwari Nagar        2
# KR Puram                    1
# Name: location, Length: 88, dtype: int64

# %%
sns.distplot(df['rate'])
# Out:
# <AxesSubplot:xlabel='rate', ylabel='Density'>

# %% [markdown]
# Almost more than 50 percent of restaurants has rating between 3 and 4. Restaurants having rating more than 4.5 are very rare.

# %% [markdown]
# # Which are the top restaurant chains in Bangaluru?

# %%
plt.figure(figsize=(10,7))
sns.barplot(x=df['name'].value_counts()[0:20],y=df['name'].value_counts()[0:20].index)
plt.title("Most famous restaurants chains in Bangaluru")
plt.xlabel("Number of outlets")
# Out:
# Text(0.5, 0, 'Number of outlets')

# %% [markdown]
# # ONLINE ORDER VS OFFLINE ORDER

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=df['online_order'],data=df)
plt.title("NUMBER OF PEOPLE WHO ORDER ONLINE")
# Out:
# Text(0.5, 1.0, 'NUMBER OF PEOPLE WHO ORDER ONLINE')

# %% [markdown]
# WE CAN SEE THAT NUMBER OF PEOPLE ORDER ONLINE ARE MORE COMPARATIVELY THEN OFFLINE.

# %% [markdown]
# # Is there any difference b/w price of restaurants accepting and not accepting online orders?

# %%
df['approx_cost(for two people)']=df['approx_cost(for two people)'].astype('int')

# %%
sns.boxplot(x='online_order',y='approx_cost(for two people)',data=df)
# Out:
# <AxesSubplot:xlabel='online_order', ylabel='approx_cost(for two people)'>

# %% [markdown]
# Restaurants accepting online orders are more affordable than Restaurants who are accepting online orders

# %%
df.dtypes
# Out:
# url                             object
# address                         object
# name                            object
# online_order                    object
# book_table                      object
# rate                           float64
# votes                            int64
# phone                           object
# location                        object
# rest_type                       object
# dish_liked                      object
# cuisines                        object
# approx_cost(for two people)      int32
# reviews_list                    object
# menu_item                       object
# listed_in(type)                 object
# listed_in(city)                 object
# dtype: object

# %%
df[(df['rate']>=4)]
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 7      https://www.zomato.com/bangalore/onesta-banash...
# 8      https://www.zomato.com/bangalore/penthouse-caf...
# 9      https://www.zomato.com/bangalore/smacznego-ban...
# ...                                                  ...
# 51700  https://www.zomato.com/bangalore/bar-bar-white...
# 51701  https://www.zomato.com/bangalore/the-beer-cafe...
# 51702  https://www.zomato.com/bangalore/pablos-gastro...
# 51704  https://www.zomato.com/bangalore/smaaash-white...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 7      2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# ...

# %% [markdown]
# # How many of the restuarants do not accept online orders?

# %%
x=df['book_table'].value_counts()
labels=['not book','book']
plt.pie(x,explode=[0.0,0.1],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e299bd59a0>,
# ...
#  [Text(-0.7422740453458221, 0.8118061601182566, ''),
#   Text(0.809753421097135, -0.8856067959435985, '')],
#  [Text(-0.404876752006812, 0.44280336006450355, '73.6%'),
#   Text(0.472356162306662, -0.5166039643004324, '26.4%')])

# %%
x=df['online_order'].value_counts()
labels=['YES','NO']
plt.pie(x,explode=[0.0,0.1],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e299c26fd0>,
# ...
#  [Text(-0.6609964255137607, 0.8792517986663614, ''),
#   Text(0.7210870096513753, -0.9591837803633034, '')],
#  [Text(-0.3605435048256876, 0.4795918901816516, '70.5%'),
#   Text(0.4206340889633022, -0.5595238718785936, '29.5%')])

# %% [markdown]
# # How many types of restaurants we have?

# %%
df['rest_type'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(20,12))
df['rest_type'].value_counts().nlargest(20).plot.bar(color='red')
plt.show()

# %% [markdown]
# At all, Banglore is known as the tech capital of India,people having busy and modern life will prefer casual dinning.
# We can observe tha casual dinning type restaurants dominates.

# %% [markdown]
# # highest voted restaurant

# %%
df.groupby('name')['votes'].max().nlargest(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='name'>

# %% [markdown]
# Byg Brewing Company got the heighest number of votes.

# %%
plt.figure(figsize=(20,12))
df['dish_liked'].value_counts().nlargest(15).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Biryani is the most liked dish

# %% [markdown]
# # cost vs rating

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x="rate",y="approx_cost(for two people)",hue="online_order",data=df)
plt.show()

# %% [markdown]
# from this scattterplot,we can come up with a conclusion that most of the highest rated accepts online order and they r budgeted too compared to offline order.

# %% [markdown]
# # TOP DISHES IN COUNT

# %%
plt.figure(figsize=(20,12))
df['approx_cost(for two people)'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# here we can see that 400,500 and 600 disges are maximum in count

# %% [markdown]
# # All the restautant that are below than 500(budget hotel)

# %%
df[df['approx_cost(for two people)']<500]
# Out:
#                                                      url  \
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 13     https://www.zomato.com/bangalore/caf-eleven-ba...
# 18     https://www.zomato.com/bangalore/t3h-cafe-bana...
# 20     https://www.zomato.com/bangalore/the-vintage-c...
# 40     https://www.zomato.com/bangalore/chaatimes-bas...
# ...                                                  ...
# 51598  https://www.zomato.com/bangalore/the-grilled-f...
# 51601  https://www.zomato.com/bangalore/khan-saheb-gr...
# 51617  https://www.zomato.com/bangalore/breakfast-hou...
# 51629  https://www.zomato.com/bangalore/radha-rani-br...
# 51645  https://www.zomato.com/bangalore/raapchick-bro...
#
#                                                  address  \
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 13     111, Sapphire Toys Building, 100 Feet Ring Roa...
# 18     504, CJ Venkata Das Road, Padmanabhangar, 2nd ...
# ...

# %%
df_budget=df[df['approx_cost(for two people)']<=500].loc[:,('approx_cost(for two people)')]
df_budget=df_budget.reset_index()
df_budget.head()
# Out:
#    index  approx_cost(for two people)
# 0      3                          300
# 1     10                          500
# 2     12                          500
# 3     13                          450
# 4     18                          300

# %%
cuisines=df['cuisines'].value_counts()[:10]
sns.barplot(cuisines,cuisines.index)
plt.xlabel('Count')
plt.title("Most popular cuisines of Bangalore")
# Out:
# Text(0.5, 1.0, 'Most popular cuisines of Bangalore')

# %% [markdown]
# We can observe that North Indian,chinese,South Indian are most common.
# It means Bengalore is more influenced by North Indian culture more than South

# %% [markdown]
# # cost vs rating

# %%
df['approx_cost(for two people)'].value_counts()
# Out:
# 400     2471
# 500     2271
# 600     2171
# 300     1689
# 800     1662
# 1000    1246
# 700     1162
# 1200     905
# 200      862
# 1500     859
# 450      722
# 250      698
# 750      653
# 650      638
# 350      554
# 900      519
# 1300     498
# 1100     464
# 1400     446
# 550      440
# 150      367
# 2000     297
# 1600     241
# 1700     233
# 1800     189
# 3000     159
# 2500     143
# 850      122
# 100      117
# 2100      63
# 1900      58
# 950       47
# 2200      39
# 2800      31
# 3500      25
# 4000      24
# 2400      22
# 1350      18
# 180       17
# 3400      13
# 230       10
# 1250       9
# 40         8
# 1650       6
# 1450       5
# 2600       4
# 1050       4
# 4100       4
# 330        4
# 2700       2
# 3200       2
# 120        2
# 6000       2
# 4500       2
# 5000       1
# 3700       1
# 2300       1
# Name: approx_cost(for two people), dtype: int64

# %%
df['approx_cost(for two people)']=df['approx_cost(for two people)'].astype(int)

# %%
plt.figure(figsize=(20,16))
sns.scatterplot(x="rate",y='approx_cost(for two people)',hue='online_order',data=df)
plt.show()

# %% [markdown]
# from this scattterplot,we can come up with a conclusion ya most of the highest rated restraunts that accepts online order and they r budgeted too.

# %% [markdown]
# # Is there any difference b/w price of restaurants accepting and not accepting online orders?

# %%
sns.boxplot(x='online_order',y='approx_cost(for two people)',data=df)
# Out:
# <AxesSubplot:xlabel='online_order', ylabel='approx_cost(for two people)'>

# %% [markdown]
# Restaurants accepting online orders are more affordable than Restaurants who are accepting offline orders.

# %% [markdown]
# # Cheapest Rate for 2 people

# %%
df['approx_cost(for two people)'].min()
# Out:
# 40

# %% [markdown]
# # Most costly for 2 people

# %%
df['approx_cost(for two people)'].max()
# Out:
# 6000

# %% [markdown]
# # distribution of cost for 2 people

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['approx_cost(for two people)'])
plt.show()

# %% [markdown]
# most of the price lies between in a range of under 1000,it means most are affordable & very few are luxurious.

# %% [markdown]
# # Most costly Rate for 2 people is served at which Restaurant what exactly is the dish involved in this and liked dish of that restaurant

# %%
df[df['approx_cost(for two people)']==6000].loc[:,('name','cuisines','dish_liked')]
# Out:
#                                          name         cuisines  \
# 19139  Le Cirque Signature - The Leela Palace  French, Italian
# 45618  Le Cirque Signature - The Leela Palace  French, Italian
#
#                                               dish_liked
# 19139  Wine, Asparagus Soup, Creme Brulee, Pasta, Rav...
# 45618  Wine, Asparagus Soup, Creme Brulee, Pasta, Rav...

# %% [markdown]
# # Top 10 Cheapest restaurant with approx cost for 2 people

# %%
df['approx_cost(for two people)'].nsmallest(10).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Top 10 Most Expensive restaurant with approx cost for 2 people

# %%
df['approx_cost(for two people)'].nlargest(10).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Top 10 Cheapest restaurant with approx cost for 2 people

# %%
df.set_index('location',inplace=True)
df['approx_cost(for two people)'].nsmallest(10)
# Out:
# location
# Indiranagar          40
# Indiranagar          40
# Indiranagar          40
# Old Airport Road     40
# Indiranagar          40
# Domlur               40
# Domlur               40
# Old Airport Road     40
# Basavanagudi        100
# Basavanagudi        100
# Name: approx_cost(for two people), dtype: int32

# %% [markdown]
# # Which are the foodie areas?

# %%
plt.figure(figsize=(10,7))
Restaurant_locations=df['listed_in(city)'].value_counts()[:20]
sns.barplot(Restaurant_locations,Restaurant_locations.index)
# Out:
# <AxesSubplot:xlabel='listed_in(city)'>

# %% [markdown]
# #we can see that BTM, Koranmangala 7th block, Koranmangala 4th block, Koranmangala 5th block, Koranmangala 6th block has most number of restraunts.

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
df['online_order']= label_encoder.fit_transform(df['online_order'])
  
df['online_order'].unique()
# Out:
# array([1, 0])

# %%
# Encode labels in column 'book_table'.
df['book_table']= label_encoder.fit_transform(df['book_table'])
  
df['book_table'].unique()
# Out:
# array([1, 0])

# %%
plt.figure(figsize=(12,5))
sns.barplot(x=df['book_table'], y=df['rate'], data=df)
plt.show();

# %% [markdown]
# In those restraunts who have facility of booking table has slightly better rating.
